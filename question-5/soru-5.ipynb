# %%
import torch
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, output_size)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x
        
input_size = 13
hidden_size1 = 50
hidden_size2 = 100
output_size = 1

model = MLP(input_size, hidden_size1, hidden_size2, output_size)

# %%
# Dropout Regülerizasyonu
import torch
import torch.nn as nn
import torch.optim as optim


class MLP(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.dropout1 = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.dropout2 = nn.Dropout(p=0.5)
        self.fc3 = nn.Linear(hidden_size2, output_size)
        self.sigmoid = nn.Sigmoid()
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x
        
input_size = 13
hidden_size1 = 50
hidden_size2 = 100
output_size = 1

model = MLP(input_size, hidden_size1, hidden_size2, output_size)

# droppout işlemlerini kaldırıp 
#l2_lambda = 0.01
#optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=l2_lambda)
# eklersek modelimize L2 normu regülerizasyonu uygulamış oluruz

# %%
# Dosya okuma
import pandas as pd
import numpy as np
from torch.utils.data import TensorDataset

train_test = r'/content/drive/MyDrive/cure_the_princess_train.csv'
test = r'/content/drive/MyDrive/cure_the_princess_test.csv'
validation = r'/content/drive/MyDrive/cure_the_princess_validation.csv'

data_train_test = pd.read_csv(train_test)
data_test = pd.read_csv(test)
data_validation_test = pd.read_csv(validation)

# son kısmı alıp drop ediyoruz geriye özellik kısmı kalıyor bunu da değişkene atıyoruz
# y traine atıyoruz x train ile doğruluğu kontrol ediyoruz

#train loader

y_train_test = data_train_test.iloc[:, -1:].values
x_train_test = data_train_test.iloc[:, :-1].values
x_train_test = torch.tensor(x_train_test, dtype=torch.float32)
y_train_test = torch.tensor(y_train_test, dtype=torch.float32)
train_data = TensorDataset(x_train_test, y_train_test)
train_loader = torch.utils.data.DataLoader(train_data, batch_size = 16)

# test loade

y_test = data_test.iloc[:, -1:].values
x_test = data_test.iloc[:, :-1].values
x_test = torch.tensor(x_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)
test_data = TensorDataset(x_test, y_test)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = 16)

# valid loader
y_valid = data_validation_test.iloc[:, -1:].values
x_valid = data_validation_test.iloc[:, :-1].values
x_valid = torch.tensor(x_valid, dtype=torch.float32)
y_valid = torch.tensor(y_valid, dtype=torch.float32)
valid_data = TensorDataset(x_valid, y_valid)
valit_loader = torch.utils.data.DataLoader(valid_data, batch_size = 16)

# %%
learning_rate = 0.01
num_epochs = 25


num_hidden_neuron = 5000

criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)


for epoch in range(num_epochs):

    train_loss = 0.0
    train_count = 0.0
    for inputs, labels in train_loader:

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_count += 1.0
        train_loss += loss.item()

    print("Epoch", epoch, "Training loss", train_loss/train_count)

print('Finished Training')
# Out:
# Epoch 0 Training loss 0.8763658125189286
# Epoch 1 Training loss 0.6829580985292604
# Epoch 2 Training loss 0.6691299186477179
# Epoch 3 Training loss 0.614831047722056
# Epoch 4 Training loss 0.5752330316772943
# Epoch 5 Training loss 0.5688788592815399
# Epoch 6 Training loss 0.5233236796493772
# Epoch 7 Training loss 0.4835860033201266
# Epoch 8 Training loss 0.4696372645565226
# Epoch 9 Training loss 0.4514978718531283
# Epoch 10 Training loss 0.43578646926185755
# Epoch 11 Training loss 0.42928142524972746
# Epoch 12 Training loss 0.40504555460772934
# Epoch 13 Training loss 0.37119563829295243
# Epoch 14 Training loss 0.3765965256887146
# Epoch 15 Training loss 0.34518214268020436
# Epoch 16 Training loss 0.3489818250453925
# Epoch 17 Training loss 0.38534863689277743
# Epoch 18 Training loss 0.3575966022437132
# Epoch 19 Training loss 0.3345193325341502
# Epoch 20 Training loss 0.3224135364724111
# Epoch 21 Training loss 0.2961207709357708
# Epoch 22 Training loss 0.30288256794402874
# Epoch 23 Training loss 0.2957530841231346
# Epoch 24 Training loss 0.2933422775491129
# Finished Training

# %%
import seaborn as sns
import matplotlib.pyplot as plt
learning_rate = 0.01
num_epochs = 100
patience = 25

torch.manual_seed(190401071)
num_hidden_neuron = 5000

criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

list_train_loss, list_val_loss = [], []

best_val_loss = None

patience_counter = 0
for epoch in range(num_epochs):

  train_loss = 0.0
  train_count = 0.0
  for inputs, labels in train_loader:

    optimizer.zero_grad()

    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    train_count += 1.0
    train_loss += loss.item()

  val_loss = 0.0
  with torch.no_grad():
    model.eval()
    for inputs, labels in valit_loader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        val_loss += loss.item()

  model.train()

  train_loss /= train_count
  val_loss /= len(valit_loader)

  print("Epoch", epoch, "Training loss", train_loss,"Validation Loss :",val_loss)

  list_train_loss.append(train_loss)
  list_val_loss.append(val_loss)

  val_score = val_loss
  if best_val_loss is None:
    best_val_loss = val_score 
    torch.save(model.state_dict(), "checkpoint.pt")
  elif best_val_loss < val_score:
    patience_counter += 1
    print("Earlystopping Patience Counter:",patience_counter)
    if patience_counter == patience:
        break
  else:
    best_val_loss = val_score
    torch.save(model.state_dict(), "checkpoint.pt")
    patience_counter = 0

sns.set_style("darkgrid")
plt.plot(list_train_loss, label="Training loss")
plt.plot(list_val_loss, label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()


print('Finished Training')
# Out:
# Epoch 0 Training loss 0.2998735040803499 Validation Loss : 0.20082870870828629
# Epoch 1 Training loss 0.2699748908605757 Validation Loss : 0.18328314945101737
# Epoch 2 Training loss 0.27635634765972067 Validation Loss : 0.2029384456574917
# Earlystopping Patience Counter: 1
# Epoch 3 Training loss 0.27296784265509133 Validation Loss : 0.17787918485701085
# Epoch 4 Training loss 0.2775428731796108 Validation Loss : 0.18277885280549527
# Earlystopping Patience Counter: 1
# Epoch 5 Training loss 0.29398865960066833 Validation Loss : 0.18242132402956485
# Earlystopping Patience Counter: 2
# Epoch 6 Training loss 0.28029806393234036 Validation Loss : 0.17261471338570117
# Epoch 7 Training loss 0.2657552179467829 Validation Loss : 0.1757130589336157
# Earlystopping Patience Counter: 1
# Epoch 8 Training loss 0.26883853028846694 Validation Loss : 0.17507756538689137
# Earlystopping Patience Counter: 2
# Epoch 9 Training loss 0.2545320830201801 Validation Loss : 0.1626647211611271
# Epoch 10 Training loss 0.242471019678478 Validation Loss : 0.16501145474612713
# Earlystopping Patience Counter: 1
# Epoch 11 Training loss 0.2574156873588321 Validation Loss : 0.16472897715866566
# Earlystopping Patience Counter: 2
# Epoch 12 Training loss 0.2427775649990462 Validation Loss : 0.15718180388212205
# Epoch 13 Training loss 0.22407167645383486 Validation Loss : 0.1589154116809368
# Earlystopping Patience Counter: 1
# Epoch 14 Training loss 0.23381128680856922 Validation Loss : 0.1607258427888155
# Earlystopping Patience Counter: 2
# Epoch 15 Training loss 0.2406018498011782 Validation Loss : 0.16545167267322541
# Earlystopping Patience Counter: 3
# Epoch 16 Training loss 0.22399631189771846 Validation Loss : 0.16818924359977244
# Earlystopping Patience Counter: 4
# Epoch 17 Training loss 0.2473769634962082 Validation Loss : 0.16373050436377526
# Earlystopping Patience Counter: 5
# Epoch 18 Training loss 0.22455260247180733 Validation Loss : 0.17042233757674694
# Earlystopping Patience Counter: 6
# Epoch 19 Training loss 0.23230991833194903 Validation Loss : 0.16231052279472352
# Earlystopping Patience Counter: 7
# Epoch 20 Training loss 0.2316716618930237 Validation Loss : 0.16682947371155024
# Earlystopping Patience Counter: 8
# Epoch 21 Training loss 0.22136789626335796 Validation Loss : 0.15545316711068152
# Epoch 22 Training loss 0.22292785898228235 Validation Loss : 0.16243494525551797
# Earlystopping Patience Counter: 1
# Epoch 23 Training loss 0.21537925842913647 Validation Loss : 0.16282369308173655
# Earlystopping Patience Counter: 2
# Epoch 24 Training loss 0.21636454673790478 Validation Loss : 0.1614062575623393
# Earlystopping Patience Counter: 3
# Epoch 25 Training loss 0.22402717847424217 Validation Loss : 0.17101470716297626
# Earlystopping Patience Counter: 4
# Epoch 26 Training loss 0.21380166214289545 Validation Loss : 0.15093687530606986
# Epoch 27 Training loss 0.2081723755484895 Validation Loss : 0.1621500575914979
# Earlystopping Patience Counter: 1
# Epoch 28 Training loss 0.20540427143060708 Validation Loss : 0.16336960587650537
# Earlystopping Patience Counter: 2
# Epoch 29 Training loss 0.22128259409454804 Validation Loss : 0.1661278113722801
# Earlystopping Patience Counter: 3
# Epoch 30 Training loss 0.20501156905783882 Validation Loss : 0.15966362338513135
# Earlystopping Patience Counter: 4
# Epoch 31 Training loss 0.21587077584824985 Validation Loss : 0.15758025497198105
# Earlystopping Patience Counter: 5
# Epoch 32 Training loss 0.2226270780533175 Validation Loss : 0.15879189651459455
# Earlystopping Patience Counter: 6
# Epoch 33 Training loss 0.21008065276885335 Validation Loss : 0.15820048972964287
# Earlystopping Patience Counter: 7
# Epoch 34 Training loss 0.20862031911935988 Validation Loss : 0.16499116662889718
# Earlystopping Patience Counter: 8
# Epoch 35 Training loss 0.21315212066792236 Validation Loss : 0.14848700612783433
# Epoch 36 Training loss 0.20281464139683336 Validation Loss : 0.15501363556832076
# Earlystopping Patience Counter: 1
# Epoch 37 Training loss 0.21123420244342164 Validation Loss : 0.1635222550481558
# Earlystopping Patience Counter: 2
# Epoch 38 Training loss 0.20414731203566625 Validation Loss : 0.16169623490422963
# Earlystopping Patience Counter: 3
# Epoch 39 Training loss 0.21466693984745425 Validation Loss : 0.15153936427086592
# Earlystopping Patience Counter: 4
# Epoch 40 Training loss 0.1858133012075213 Validation Loss : 0.16011733524501323
# Earlystopping Patience Counter: 5
# Epoch 41 Training loss 0.20761652790670154 Validation Loss : 0.1484939306974411
# Earlystopping Patience Counter: 6
# Epoch 42 Training loss 0.19760151469160483 Validation Loss : 0.16316698845475913
# Earlystopping Patience Counter: 7
# Epoch 43 Training loss 0.1684124455846186 Validation Loss : 0.1558080840855837
# Earlystopping Patience Counter: 8
# Epoch 44 Training loss 0.21356480964754201 Validation Loss : 0.1714961787685752
# Earlystopping Patience Counter: 9
# Epoch 45 Training loss 0.1935774738181241 Validation Loss : 0.1558176524937153
# Earlystopping Patience Counter: 10
# Epoch 46 Training loss 0.17180117827993405 Validation Loss : 0.1429504869505763
# Epoch 47 Training loss 0.20649483466308705 Validation Loss : 0.16278202403336764
# Earlystopping Patience Counter: 1
# Epoch 48 Training loss 0.19007517741639404 Validation Loss : 0.1528383670374751
# Earlystopping Patience Counter: 2
# Epoch 49 Training loss 0.1719725052767162 Validation Loss : 0.16092353221029043
# Earlystopping Patience Counter: 3
# Epoch 50 Training loss 0.20831922616196585 Validation Loss : 0.14570682672783733
# Earlystopping Patience Counter: 4
# Epoch 51 Training loss 0.19226878053874155 Validation Loss : 0.1581174474209547
# Earlystopping Patience Counter: 5
# Epoch 52 Training loss 0.19105517939676211 Validation Loss : 0.14421088639646767
# Earlystopping Patience Counter: 6
# Epoch 53 Training loss 0.2081127363386788 Validation Loss : 0.16865141019225122
# Earlystopping Patience Counter: 7
# Epoch 54 Training loss 0.19823382691114763 Validation Loss : 0.16270079761743544
# Earlystopping Patience Counter: 8
# Epoch 55 Training loss 0.1881193182890928 Validation Loss : 0.14996242374181748
# Earlystopping Patience Counter: 9
# Epoch 56 Training loss 0.17404142946382112 Validation Loss : 0.1614112811163068
# Earlystopping Patience Counter: 10
# Epoch 57 Training loss 0.15991685381512852 Validation Loss : 0.14616761980578302
# Earlystopping Patience Counter: 11
# Epoch 58 Training loss 0.19361974197569526 Validation Loss : 0.15818301877006888
# Earlystopping Patience Counter: 12
# Epoch 59 Training loss 0.18138995648750775 Validation Loss : 0.14682661034166813
# Earlystopping Patience Counter: 13
# Epoch 60 Training loss 0.18160296459033898 Validation Loss : 0.14713722728192807
# Earlystopping Patience Counter: 14
# Epoch 61 Training loss 0.18222988392167452 Validation Loss : 0.16435406534001232
# Earlystopping Patience Counter: 15
# Epoch 62 Training loss 0.1869285586231117 Validation Loss : 0.14943094700574874
# Earlystopping Patience Counter: 16
# Epoch 63 Training loss 0.18797990260056302 Validation Loss : 0.14463307708501816
# Earlystopping Patience Counter: 17
# Epoch 64 Training loss 0.18212909456578236 Validation Loss : 0.150731111317873
# Earlystopping Patience Counter: 18
# Epoch 65 Training loss 0.18153600753108157 Validation Loss : 0.1571889428421855
# Earlystopping Patience Counter: 19
# Epoch 66 Training loss 0.17643037766123873 Validation Loss : 0.1711036181077361
# Earlystopping Patience Counter: 20
# Epoch 67 Training loss 0.18088645403143727 Validation Loss : 0.15362005177885293
# Earlystopping Patience Counter: 21
# Epoch 68 Training loss 0.17696884757827355 Validation Loss : 0.1500003439374268
# Earlystopping Patience Counter: 22
# Epoch 69 Training loss 0.1869032824105477 Validation Loss : 0.16327970065176486
# Earlystopping Patience Counter: 23
# Epoch 70 Training loss 0.16139578684881517 Validation Loss : 0.14515376752242445
# Earlystopping Patience Counter: 24
# Epoch 71 Training loss 0.17957540841985353 Validation Loss : 0.15754476841539145
# Earlystopping Patience Counter: 25
# Finished Training

# %%
from torcheval.metrics.functional import multiclass_f1_score
from torcheval.metrics.functional import multiclass_accuracy
import numpy
model.load_state_dict(torch.load('checkpoint.pt'))

predictions = []
ground_truths = []

model.eval()
with torch.no_grad():
  for inputs,masks in test_loader:
    outputs = model(inputs)
    _,predicted = torch.max(outputs.data,1)
    predictions.extend(predicted.tolist())
    ground_truths.extend(masks.tolist())

ground_truths = torch.tensor(ground_truths)
predictions = torch.tensor(predictions)
ground_truths = ground_truths.squeeze()

f1_score = multiclass_f1_score(predictions,ground_truths.to(torch.int64),num_classes=2,average='macro')
accuracy = multiclass_accuracy(predictions,ground_truths)

print("F1-Score: {:.4f}\nAccuracy: {:.4f}".format(f1_score,accuracy))
# Out:
# F1-Score: 0.3322
# Accuracy: 0.4974

# %%
model.load_state_dict(torch.load('checkpoint.pt'))
model.eval()
predicts =[]
real_labels = list()
with torch.no_grad():
  for inputs,label in test_loader:
    outputs = model(inputs)
    _,predict = torch.max(outputs.data,1)
    predicts.extend(predict.tolist())
    real_labels.extend(label.tolist())


from sklearn.metrics import f1_score,accuracy_score,classification_report
print("Accuracy score of this model: {}".format(accuracy_score(real_labels,predicts)))
print(classification_report(real_labels,predicts))
# Out:
# Accuracy score of this model: 0.49740932642487046
#               precision    recall  f1-score   support
#
#          0.0       0.50      1.00      0.66       384
#          1.0       0.00      0.00      0.00       388
#
#     accuracy                           0.50       772
#    macro avg       0.25      0.50      0.33       772
# weighted avg       0.25      0.50      0.33       772
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
